# %% [markdown]
# # Scaling Law Experiments

# %%
wandb_project = "scaling-law-pythia70m-torchtitan"

lr_sweep = "1e-6,1e-5,1e-4,3e-4,5e-4,7e-4,8e-4,9e-4,1e-3,2e-3,3e-3,5e-3,7e-3"
seed_sweep = "1"

for i in range(13, 13+16):

    dataset = f"Recipe_{i}"

    cmd = f"sbatch run_train_sweep_full.sh --dataset {dataset} --grid optimizer.lr={lr_sweep} --grid debug.seed={seed_sweep} --wandb-project {wandb_project} ;"
    print(cmd)

print('')

for i in range(29, 38):

    dataset = f"Recipe_{i}"

    cmd = f"sbatch run_train_sweep_full.sh --dataset {dataset} --grid optimizer.lr={lr_sweep} --grid debug.seed={seed_sweep} --wandb-project {wandb_project} ;"
    print(cmd)
# Out:
# sbatch run_train_sweep_full.sh --dataset Recipe_13 --grid optimizer.lr=1e-6,1e-5,1e-4,3e-4,5e-4,7e-4,8e-4,9e-4,1e-3,2e-3,3e-3,5e-3,7e-3 --grid debug.seed=1 --wandb-project scaling-law-pythia70m-torchtitan ;
# sbatch run_train_sweep_full.sh --dataset Recipe_14 --grid optimizer.lr=1e-6,1e-5,1e-4,3e-4,5e-4,7e-4,8e-4,9e-4,1e-3,2e-3,3e-3,5e-3,7e-3 --grid debug.seed=1 --wandb-project scaling-law-pythia70m-torchtitan ;
# sbatch run_train_sweep_full.sh --dataset Recipe_15 --grid optimizer.lr=1e-6,1e-5,1e-4,3e-4,5e-4,7e-4,8e-4,9e-4,1e-3,2e-3,3e-3,5e-3,7e-3 --grid debug.seed=1 --wandb-project scaling-law-pythia70m-torchtitan ;
# sbatch run_train_sweep_full.sh --dataset Recipe_16 --grid optimizer.lr=1e-6,1e-5,1e-4,3e-4,5e-4,7e-4,8e-4,9e-4,1e-3,2e-3,3e-3,5e-3,7e-3 --grid debug.seed=1 --wandb-project scaling-law-pythia70m-torchtitan ;
# ...

# %% [markdown]
# ```
# Submitted batch job 3182096
# Submitted batch job 3182097
# Submitted batch job 3182098
# Submitted batch job 3182099
# Submitted batch job 3182100
# Submitted batch job 3182101
# Submitted batch job 3182102
# Submitted batch job 3182103
# Submitted batch job 3182104
# Submitted batch job 3182105
# Submitted batch job 3182106
# Submitted batch job 3182107
# Submitted batch job 3182108
# Submitted batch job 3182109
# Submitted batch job 3182110
# Submitted batch job 3182111
# Submitted batch job 3182112
# Submitted batch job 3182113
# Submitted batch job 3182114
# Submitted batch job 3182115
# Submitted batch job 3182116
# Submitted batch job 3182117
# Submitted batch job 3182118
# Submitted batch job 3182119
# Submitted batch job 3182120
# ```

# %%
seed_sweep = "3"

plilc = '--partition=pli-lc --account=ai2_data'
pli = '--partition=pli --account=datavaluation'
time = '--time=20:59:59'

for i in range(13, 13+16):

    dataset = f"Recipe_{i}"

    cmd = f"sbatch {plilc} {time} run_train_sweep_full.sh --dataset {dataset} --grid optimizer.lr={lr_sweep} --grid debug.seed={seed_sweep} --wandb-project {wandb_project} ;"
    print(cmd)

print('')

for i in range(29, 38):

    dataset = f"Recipe_{i}"

    cmd = f"sbatch {pli} {time} run_train_sweep_full.sh --dataset {dataset} --grid optimizer.lr={lr_sweep} --grid debug.seed={seed_sweep} --wandb-project {wandb_project} ;"
    print(cmd)
# Out:
# sbatch --partition=pli-lc --account=ai2_data --time=20:59:59 run_train_sweep_full.sh --dataset Recipe_13 --grid optimizer.lr=1e-6,1e-5,1e-4,3e-4,5e-4,7e-4,8e-4,9e-4,1e-3,2e-3,3e-3,5e-3,7e-3 --grid debug.seed=3 --wandb-project scaling-law-pythia70m-torchtitan ;
# sbatch --partition=pli-lc --account=ai2_data --time=20:59:59 run_train_sweep_full.sh --dataset Recipe_14 --grid optimizer.lr=1e-6,1e-5,1e-4,3e-4,5e-4,7e-4,8e-4,9e-4,1e-3,2e-3,3e-3,5e-3,7e-3 --grid debug.seed=3 --wandb-project scaling-law-pythia70m-torchtitan ;
# sbatch --partition=pli-lc --account=ai2_data --time=20:59:59 run_train_sweep_full.sh --dataset Recipe_15 --grid optimizer.lr=1e-6,1e-5,1e-4,3e-4,5e-4,7e-4,8e-4,9e-4,1e-3,2e-3,3e-3,5e-3,7e-3 --grid debug.seed=3 --wandb-project scaling-law-pythia70m-torchtitan ;
# ...

# %%
for i in range(3182277, 3182301+1):
    print(f"scancel {i} ;")
# Out:
# scancel 3182277 ;
# scancel 3182278 ;
# scancel 3182279 ;
# scancel 3182280 ;
# scancel 3182281 ;
# scancel 3182282 ;
# scancel 3182283 ;
# scancel 3182284 ;
# scancel 3182285 ;
# scancel 3182286 ;
# scancel 3182287 ;
# scancel 3182288 ;
# scancel 3182289 ;
# scancel 3182290 ;
# scancel 3182291 ;
# scancel 3182292 ;
# scancel 3182293 ;
# scancel 3182294 ;
# scancel 3182295 ;
# scancel 3182296 ;
# scancel 3182297 ;
# scancel 3182298 ;
# scancel 3182299 ;
# scancel 3182300 ;
# scancel 3182301 ;
